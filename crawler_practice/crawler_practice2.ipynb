# %%
import pandas as pd
url = 'http://www.stockq.org/market/asia.php'
c = pd.read_html(url)[7]
c
# Out:
#                          0         1        2       3         4         5  \
# 0   亞洲股市行情 (Asian Markets)       NaN      NaN     NaN       NaN       NaN
# 1                       股市        指數       漲跌      比例        最高        最低
# 2                      紐西蘭  7407.612   -22.33  -0.30%  7445.210  7407.610
# 3                     澳洲股市   5882.20    13.80   0.24%   5901.40   5867.80
# 4                    日經225  19919.82    49.97   0.25%  19998.49  19862.41
# 5                     東證一部   1584.23     4.23   0.27%   1590.70   1580.46
# 6                     東證二部    5897.6     7.28   0.12%   5910.07   5887.47
# 7                   JASDAQ    136.99     0.41   0.30%     137.1    136.76
# 8                     韓國股市   2295.33     4.68   0.20%   2309.00   2283.84
# 9                     台灣加權  10031.49    -5.33  -0.05%  10058.59   9991.08
# 10                    台灣店頭    132.42    -0.51  -0.38%    133.61    132.04
# 11                    上海綜合  3112.964    22.73   0.74%  3113.512  3060.534
# ...

# %%
c = c.drop(c.columns[[0]],axis=0)
c
# Out:
#          0         1        2       3         4         5         6       7  \
# 1       股市        指數       漲跌      比例        最高        最低        開盤    今年表現
# 2      紐西蘭  7407.612   -22.33  -0.30%  7445.210  7407.610  7429.940   7.65%
# 3     澳洲股市   5882.20    13.80   0.24%   5901.40   5867.80     2.85%   16:37
# 4    日經225  19919.82    49.97   0.25%  19998.49  19862.41  19953.06   4.21%
# 5     東證一部   1584.23     4.23   0.27%   1590.70   1580.46   1587.79   4.32%
# 6     東證二部    5897.6     7.28   0.12%   5910.07   5887.47   5895.23  12.77%
# 7   JASDAQ    136.99     0.41   0.30%     137.1    136.76    136.89  11.64%
# 8     韓國股市   2295.33     4.68   0.20%   2309.00   2283.84   2306.73  13.27%
# 9     台灣加權  10031.49    -5.33  -0.05%  10058.59   9991.08  10037.58   8.41%
# 10    台灣店頭    132.42    -0.51  -0.38%    133.61    132.04    132.93   5.78%
# 11    上海綜合  3112.964    22.73   0.74%  3113.512  3060.534  3082.872   0.30%
# ...

# %%
table = pd.read_html(url)[4]
table
# Out:
#                                                   0    \
# 0   市場動態 全球股市排行榜 相對低檔股市指數 相對高檔股市指數 亞洲股市指數 歐洲股市、非洲指...
# 1   市場動態 全球股市排行榜 相對低檔股市指數 相對高檔股市指數 亞洲股市指數 歐洲股市、非洲指...
# 2                      亞洲股市指數 刷新時間 2017/5/16 16:33:01
# 3                              亞洲股市行情 (Asian Markets)
# 4                                                  股市
# 5                                                 紐西蘭
# 6                                                澳洲股市
# 7                                               日經225
# 8                                                東證一部
# 9                                                東證二部
# 10                                             JASDAQ
# 11                                               韓國股市
# 12                                               台灣加權
# 13                                               台灣店頭
# 14                                               上海綜合
# 15                                               上海A股
# ...

# %%
table = table.drop(table.columns[range(5)],axis=0)
table
# Out:
#                                                   0         1        2    \
# 5                                                 紐西蘭  7407.612   -22.33
# 6                                                澳洲股市   5882.20    13.80
# 7                                               日經225  19919.82    49.97
# 8                                                東證一部   1584.23     4.23
# 9                                                東證二部    5897.6     7.28
# 10                                             JASDAQ    136.99     0.41
# 11                                               韓國股市   2295.33     4.68
# 12                                               台灣加權  10031.49    -5.33
# 13                                               台灣店頭    132.42    -0.51
# 14                                               上海綜合  3112.964    22.73
# 15                                               上海A股  3259.964    23.77
# 16                                               上海B股   325.271     3.58
# ...

# %%
table = table.drop(table.columns[9:293],axis=1)
table
# Out:
#                                                   0         1        2    \
# 5                                                 紐西蘭  7407.612   -22.33
# 6                                                澳洲股市   5882.20    13.80
# 7                                               日經225  19919.82    49.97
# 8                                                東證一部   1584.23     4.23
# 9                                                東證二部    5897.6     7.28
# 10                                             JASDAQ    136.99     0.41
# 11                                               韓國股市   2295.33     4.68
# 12                                               台灣加權  10031.49    -5.33
# 13                                               台灣店頭    132.42    -0.51
# 14                                               上海綜合  3112.964    22.73
# 15                                               上海A股  3259.964    23.77
# 16                                               上海B股   325.271     3.58
# ...

# %%
table[0]
# Out:
# 5                                                   紐西蘭
# 6                                                  澳洲股市
# 7                                                 日經225
# 8                                                  東證一部
# 9                                                  東證二部
# 10                                               JASDAQ
# 11                                                 韓國股市
# 12                                                 台灣加權
# 13                                                 台灣店頭
# 14                                                 上海綜合
# 15                                                 上海A股
# 16                                                 上海B股
# 17                                                 深圳A股
# 18                                                 深圳B股
# 19                                                滬深300
# 20                                                 深證成指
# 21                                                 中小板指
# ...
